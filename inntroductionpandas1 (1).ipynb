# %%
import pandas as pd

cars = pd.Series (["BMW", "AUDIO", "FORD"])
cars
# Out:
# 0      BMW
# 1    AUDIO
# 2     FORD
# dtype: object

# %%
colors = pd.Series(["red", "green", "marron"])
colors
# Out:
# 0       red
# 1     green
# 2    marron
# dtype: object

# %%
# !wget https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales.csv
# Out:
# --2024-01-27 12:35:34--  https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv.4’
#
# car-sales.csv.4     100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-01-27 12:35:34 (6.40 MB/s) - ‘car-sales.csv.4’ saved [369/369]

# %%
 data = pd.read_csv("/content/car-sales.csv")
 data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# # Новый раздел

# %%
data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
data["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
data.to_csv("v")

# %%
a= pd.read_csv("/content/v")
a
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
data.mean()
# Out:
# <ipython-input-177-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
data.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
data,[data["Make"] == "Toyota"]
# Out:
# (     Make Colour  Odometer (KM)  Doors       Price
#  0  Toyota  White         150043      4   $4,000.00
#  1   Honda    Red          87899      4   $5,000.00
#  2  Toyota   Blue          32549      3   $7,000.00
#  3     BMW  Black          11179      5  $22,000.00
#  4  Nissan  White         213095      4   $3,500.00
#  5  Toyota  Green          99213      4   $4,500.00
#  6   Honda   Blue          45698      4   $7,500.00
#  7   Honda   Blue          54738      4   $7,000.00
#  8  Toyota  White          60000      4   $6,250.00
#  9  Nissan  White          31600      4   $9,700.00,
#  [0     True
#   1    False
#   2     True
#   3    False
#   4    False
#   5     True
#   6    False
#   7    False
#   8     True
#   9    False
#   Name: Make, dtype: bool])

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
data['Doors'].hist()
# Out:
# <Axes: >

# %%
data["Price"]=data["Price"].str.replace('[\$\,]|\.\d*', '', regex=True).astype(int)

# %%
data['Price'].plot()
# Out:
# <Axes: >

# %%
pd.crosstab(data["Make"], data["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
data.groupby("Make") ["Price"].sum()
# Out:
# Make
# BMW       22000
# Honda     19500
# Nissan    13200
# Toyota    21750
# Name: Price, dtype: int64

# %%
# !wget https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales-missing-data.csv
# Out:
# --2024-01-27 12:35:35--  https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv.4’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-01-27 12:35:35 (14.7 MB/s) - ‘car-sales-missing-data.csv.4’ saved [287/287]

# %%
car_sales_missing_data=pd.read_csv("/content/car-sales-missing-data.csv")
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_data['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing_data['Odometer'] =car_sales_missing_data['Odometer'].fillna (car_sales_missing_data['Odometer'].mean())
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing_data.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing_data['Sits'] = 4
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Sits
# 0  Toyota  White  150043.000000    4.0   $4,000     4
# 1   Honda    Red   87899.000000    4.0   $5,000     4
# 2  Toyota   Blue   92302.666667    3.0   $7,000     4
# 3     BMW  Black   11179.000000    5.0  $22,000     4
# 4  Nissan  White  213095.000000    4.0   $3,500     4
# 5  Toyota  Green   92302.666667    4.0   $4,500     4
# 6   Honda    NaN   92302.666667    4.0   $7,500     4
# 7   Honda   Blue   92302.666667    4.0      NaN     4
# 8  Toyota  White   60000.000000    NaN      NaN     4
# 9     NaN  White   31600.000000    4.0   $9,700     4

# %%
car_sales_missing_data['Engin']=[3.2,2.2,5.5,3.4,1.3,6.5,2.3,4.5,4.2,22]
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Sits  Engin
# 0  Toyota  White  150043.000000    4.0   $4,000     4    3.2
# 1   Honda    Red   87899.000000    4.0   $5,000     4    2.2
# 2  Toyota   Blue   92302.666667    3.0   $7,000     4    5.5
# 3     BMW  Black   11179.000000    5.0  $22,000     4    3.4
# 4  Nissan  White  213095.000000    4.0   $3,500     4    1.3
# 5  Toyota  Green   92302.666667    4.0   $4,500     4    6.5
# 6   Honda    NaN   92302.666667    4.0   $7,500     4    2.3
# 7   Honda   Blue   92302.666667    4.0      NaN     4    4.5
# 8  Toyota  White   60000.000000    NaN      NaN     4    4.2
# 9     NaN  White   31600.000000    4.0   $9,700     4   22.0

# %%
df = pd.DataFrame(["Dog","Fish","Mouse", "Horse"], index=[2,2,3,4])
df
# Out:
#        0
# 2    Dog
# 2   Fish
# 3  Mouse
# 4  Horse

# %%
df.loc[2]
# Out:
#       0
# 2   Dog
# 2  Fish

# %%
import pandas

# %%
colors =pd.Series(["red","green","blue"])
colors
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
cars = pd.Series(["Audi", "Ford", "BMW"])
cars
# Out:
# 0    Audi
# 1    Ford
# 2     BMW
# dtype: object

# %%
cars = pd.DataFrame({"cars" : cars,
                     "colors": colors})
cars
# Out:
#    cars colors
# 0  Audi    red
# 1  Ford  green
# 2   BMW   blue

# %%
pd.read_csv("/content/car-sales.csv")
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data.to_csv("a")

# %%
data["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
data.describe()
# Out:
#        Odometer (KM)      Doors         Price
# count      10.000000  10.000000     10.000000
# mean    78601.400000   4.000000   7645.000000
# std     61983.471735   0.471405   5379.407753
# min     11179.000000   3.000000   3500.000000
# 25%     35836.250000   4.000000   4625.000000
# 50%     57369.000000   4.000000   6625.000000
# 75%     96384.500000   4.000000   7375.000000
# max    213095.000000   5.000000  22000.000000

# %%
data["Price"].mean()
# Out:
# 7645.0

# %%
data["Price"].sum()
# Out:
# 76450

# %%
data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(data["Make"])
# Out:
# 10

# %%
data.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df.loc[2]
# Out:
#       0
# 2   Dog
# 2  Fish

# %%
df.iloc[3]
# Out:
# 0    Horse
# Name: 4, dtype: object

# %%
df = pd.DataFrame(["red","green", "grey"], index=[1,2,3])
df
# Out:
#        0
# 1    red
# 2  green
# 3   grey

# %%
# !wget https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales.csv
# Out:
# --2024-01-27 12:35:35--  https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv.5’
#
# car-sales.csv.5     100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-01-27 12:35:36 (7.90 MB/s) - ‘car-sales.csv.5’ saved [369/369]

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/car-sales.csv")
data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
data['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
data['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
data[data["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(data["Make"], data["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
data.groupby("Make")['Odometer (KM)'].mean()
# Out:
# Make
# BMW        11179.000000
# Honda      62778.333333
# Nissan    122347.500000
# Toyota     85451.250000
# Name: Odometer (KM), dtype: float64

# %%
# !wget https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales-missing-data.csv
# Out:
# --2024-01-27 12:35:36--  https://raw.githubusercontent.com/Rstam59/Codelandia/main/car-sales-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 287 [text/plain]
# Saving to: ‘car-sales-missing-data.csv.5’
#
# car-sales-missing-d 100%[===================>]     287  --.-KB/s    in 0s
#
# 2024-01-27 12:35:36 (7.16 MB/s) - ‘car-sales-missing-data.csv.5’ saved [287/287]

# %%
car_sales_missing_data = pd.read_csv("/content/car-sales-missing-data.csv")
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_data["Odometer"].plot()
# Out:
# <Axes: >

# %%
car_sales_missing_data["Odometer"].hist()
# Out:
# <Axes: >

# %%
car_sales_missing_data["Price"]=data["Price"].str.replace('[\$\,]|\.\d*', '', regex=True).astype(int)

# %%
car_sales_missing_data["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales_missing_data.dropna()
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0   4000
# 1   Honda    Red   87899.0    4.0   5000
# 3     BMW  Black   11179.0    5.0  22000
# 4  Nissan  White  213095.0    4.0   3500

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_missing_data
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White  150043.0    4.0   4000
# 1   Honda    Red   87899.0    4.0   5000
# 2  Toyota   Blue       NaN    3.0   7000
# 3     BMW  Black   11179.0    5.0  22000
# 4  Nissan  White  213095.0    4.0   3500
# 5  Toyota  Green       NaN    4.0   4500
# 6   Honda    NaN       NaN    4.0   7500
# 7   Honda   Blue       NaN    4.0   7000
# 8  Toyota  White   60000.0    NaN   6250
# 9     NaN  White   31600.0    4.0   9700

# %%
car_sales_missing_data.mean()
# Out:
# <ipython-input-230-5d0d59121515>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales_missing_data.mean()
# Odometer    92302.666667
# Doors           4.000000
# Price        7645.000000
# dtype: float64

# %%
y = car_sales_missing_data["Make"].str.lower()
y
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9       NaN
# Name: Make, dtype: object

# %%
car_sales_missing_data["Odometer"] = car_sales_missing_data["Odometer"].fillna(car_sales_missing_data["Odometer"].mean())
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda    NaN   92302.666667    4.0   7500
# 7   Honda   Blue   92302.666667    4.0   7000
# 8  Toyota  White   60000.000000    NaN   6250
# 9     NaN  White   31600.000000    4.0   9700

# %%
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda    NaN   92302.666667    4.0   7500
# 7   Honda   Blue   92302.666667    4.0   7000
# 8  Toyota  White   60000.000000    NaN   6250
# 9     NaN  White   31600.000000    4.0   9700

# %%
df = pd.DataFrame(car_sales_missing_data)
df
# Out:
#      Make Colour       Odometer  Doors  Price
# 0  Toyota  White  150043.000000    4.0   4000
# 1   Honda    Red   87899.000000    4.0   5000
# 2  Toyota   Blue   92302.666667    3.0   7000
# 3     BMW  Black   11179.000000    5.0  22000
# 4  Nissan  White  213095.000000    4.0   3500
# 5  Toyota  Green   92302.666667    4.0   4500
# 6   Honda    NaN   92302.666667    4.0   7500
# 7   Honda   Blue   92302.666667    4.0   7000
# 8  Toyota  White   60000.000000    NaN   6250
# 9     NaN  White   31600.000000    4.0   9700

# %%
df.dropna(inplace =  True)

# %%
car_sales_missing_data["Seats"] = 5
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats
# 0  Toyota  White  150043.000000    4.0   4000      5
# 1   Honda    Red   87899.000000    4.0   5000      5
# 2  Toyota   Blue   92302.666667    3.0   7000      5
# 3     BMW  Black   11179.000000    5.0  22000      5
# 4  Nissan  White  213095.000000    4.0   3500      5
# 5  Toyota  Green   92302.666667    4.0   4500      5
# 6   Honda    NaN   92302.666667    4.0   7500      5
# 7   Honda   Blue   92302.666667    4.0   7000      5
# 8  Toyota  White   60000.000000    NaN   6250      5
# 9     NaN  White   31600.000000    4.0   9700      5

# %%
car_sales_missing_data["Engine Size"] = [1.3, 1.5, 2.3, 3.3, 22, 36, 3.9, 4, 4.1,4.5]

car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.3
# 3     BMW  Black   11179.000000    5.0  22000      5          3.3
# 4  Nissan  White  213095.000000    4.0   3500      5         22.0
# 5  Toyota  Green   92302.666667    4.0   4500      5         36.0
# 6   Honda    NaN   92302.666667    4.0   7500      5          3.9
# 7   Honda   Blue   92302.666667    4.0   7000      5          4.0
# 8  Toyota  White   60000.000000    NaN   6250      5          4.1
# 9     NaN  White   31600.000000    4.0   9700      5          4.5

# %%
car_sales_missing_data["Kilometer"] = [100,200,250,330,126,230,96,782,563,500]
car_sales_missing_data
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  Kilometer
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3        100
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5        200
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.3        250
# 3     BMW  Black   11179.000000    5.0  22000      5          3.3        330
# 4  Nissan  White  213095.000000    4.0   3500      5         22.0        126
# 5  Toyota  Green   92302.666667    4.0   4500      5         36.0        230
# 6   Honda    NaN   92302.666667    4.0   7500      5          3.9         96
# 7   Honda   Blue   92302.666667    4.0   7000      5          4.0        782
# 8  Toyota  White   60000.000000    NaN   6250      5          4.1        563
# 9     NaN  White   31600.000000    4.0   9700      5          4.5        500

# %%
df = pd.DataFrame(car_sales_missing_data)
df
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  Kilometer
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3        100
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5        200
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.3        250
# 3     BMW  Black   11179.000000    5.0  22000      5          3.3        330
# 4  Nissan  White  213095.000000    4.0   3500      5         22.0        126
# 5  Toyota  Green   92302.666667    4.0   4500      5         36.0        230
# 6   Honda    NaN   92302.666667    4.0   7500      5          3.9         96
# 7   Honda   Blue   92302.666667    4.0   7000      5          4.0        782
# 8  Toyota  White   60000.000000    NaN   6250      5          4.1        563
# 9     NaN  White   31600.000000    4.0   9700      5          4.5        500

# %%
df = df.drop("Kilometer", axis = 1)
df
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3
# 1   Honda    Red   87899.000000    4.0   5000      5          1.5
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.3
# 3     BMW  Black   11179.000000    5.0  22000      5          3.3
# 4  Nissan  White  213095.000000    4.0   3500      5         22.0
# 5  Toyota  Green   92302.666667    4.0   4500      5         36.0
# 6   Honda    NaN   92302.666667    4.0   7500      5          3.9
# 7   Honda   Blue   92302.666667    4.0   7000      5          4.0
# 8  Toyota  White   60000.000000    NaN   6250      5          4.1
# 9     NaN  White   31600.000000    4.0   9700      5          4.5
